# %%
# numpy imports
import numpy as np
from numpy import dot
from numpy.linalg import norm

from gensim.models import Word2Vec
from gensim.test.utils import common_texts, get_tmpfile
import gensim.downloader as api

# %%
model = api.load("glove-twitter-50")

# %%
def get_vectors(word1, word2):
    try:
        vec1 = model[word1]/norm(model[word1])
    except:
        print('Word1 is not present in the model')
        
    try:
        vec2 = model[word2]/norm(model[word2])
    except:
        print('Word2 is not present in the model')
        
    return vec1, vec2

# %%
def cosine_similarity(word1, word2):
    try:
        v1, v2 = get_vectors(word1, word2)
    except:
        return
    cos_sim = dot(v1, v2)/(norm(v1)*norm(v2))
    return cos_sim

# %%
def euclidean_distance(word1, word2):
    try:
        v1, v2 = get_vectors(word1, word2)
    except:
        return
    dist = 1/(1 + norm(v1 - v2))
    return dist

# %%
word1 = 'ass'
word2 = 'donkey'

print(cosine_similarity(word1, word2))
print(euclidean_distance(word1, word2))
# Out:
# 0.64861095
# 0.5439753343093442

# %% [markdown]
# word1     word2     Cosine       Euclidean
#
# War       Spear     0.24926732   0.25380212
# Cat       Dog       0.9429585    0.06486539

# %%
 arr = [["restricted", "nature", "aspect"],
["character", "necessary", "mandatory"],
["requisite", "negate", "contradict"],
["refute", "negligent", "careless"],
["remiss", "negotiate", "bargain"],
["deal", "nice", "affable"],
["benign", "noble", "aristocratic"],
["distinguished", "novice", "beginner"],
["nonprofessional", "nuisance", "annoyance"],
["loyal", "objection", "disapproval"],
["protest", "obligatory", "compulsory"],
["required", "observe", "notice"],
["watch", "obvious", "conspicuous"],
["definite", "offend", "anger"],
["irritate", "offer", "bid"],
["proposal", "omen", "premonition"],
["sign", "omit", "exclude"],
["remove", "opportune", "advantageous"],
["placate", "pain", "ache"],
["discomfort", "paramount", "chief"],
["leading", "partisan", "biased"],
["dogmatic", "passive", "inactive"],
["lethargic", "pause", "break"],
["cease", "permeate", "diffuse"],
["disseminate", "perpetuate", "endure"],
["preserve", "perplex", "astonish"],
["baffle", "persecute", "afflict"],
["emanate", "radical", "basic"],
["fundamental", "range", "anger"],
["furor", "rank", "arrange"],
["classify", "realize", "accomplish"],
["fulfill", "recalcitrant", "obstinate"],
["stubborn", "receptacle", "container"],
["repository", "reconcile", "atone"],
["conciliate", "regret", "deplore"],
["grieve", "reliable", "dependable"],
["permit", "scope", "aim"],
["extent", "section", "division"],
["portion", "settle", "adjust"],
["compromise", "shallow", "superficial"],
["trivial", "shrewd", "careful"],
["calculating", "significant", "distinctive"],
["important", "slight", "delicate"],
["slender", "spontaneous", "impromptu"],
["unplanned", "spread", "announce"],
["broadcast", "stabilize", "balance"],
["subdue", "tangle", "intertwine"],
["twist", "temper", "mood"],
["nature", "tendency", "inclination"],
["trend", "term", "cycle"],
["duration", "thrift", "conservation"],
["prudence", "tough", "aggressive"],
["unyielding", "transfer", "convey"],
["exchange", "tumult", "agitation"],
["commotion", "turbulent", "disordered"],
["inflated", "valid", "authorized"],
["legitimate", "variety", "assortment"],
["diversify", "verify", "authenticate"]]

# %%
cs = [1, 1, 1]
ed = [1, 1, 1]
for i in range(len(arr)):
    cs[0] = [arr[i][0], arr[i][1], cosine_similarity(arr[i][0], arr[i][1])]
    ed[0] = [arr[i][0], arr[i][1], euclidean_distance(arr[i][0], arr[i][1])]
    cs[1] = [arr[i][1], arr[i][2], cosine_similarity(arr[i][1], arr[i][2])]
    ed[1] = [arr[i][1], arr[i][2], euclidean_distance(arr[i][1], arr[i][2])]
    cs[2] = [arr[i][0], arr[i][2], cosine_similarity(arr[i][0], arr[i][2])]
    ed[2] = [arr[i][0], arr[i][2], euclidean_distance(arr[i][0], arr[i][2])]
    try:
        for j in range(3):
            if cs[j][2] < 0.3:
                print(cs[j][0], '\t\t', cs[j][1], '\t\tCosine Similarity = ', cs[j][2], sep = '')
    except:
        pass
    
for i in range(len(arr)):
    cs[0] = [arr[i][0], arr[i][1], cosine_similarity(arr[i][0], arr[i][1])]
    ed[0] = [arr[i][0], arr[i][1], euclidean_distance(arr[i][0], arr[i][1])]
    cs[1] = [arr[i][1], arr[i][2], cosine_similarity(arr[i][1], arr[i][2])]
    ed[1] = [arr[i][1], arr[i][2], euclidean_distance(arr[i][1], arr[i][2])]
    cs[2] = [arr[i][0], arr[i][2], cosine_similarity(arr[i][0], arr[i][2])]
    ed[2] = [arr[i][0], arr[i][2], euclidean_distance(arr[i][0], arr[i][2])]
    try:
        for j in range(3):
            if ed[j][2] < 0.5:
                print(ed[j][0], '\t\t', ed[j][1], '\t\tEuclidean Similarity = ', ed[j][2], sep = '')

    except:
        pass
# Out:
# restricted		nature		Cosine Similarity = 0.23243318
# requisite		contradict		Cosine Similarity = 0.20010321
# refute		careless		Cosine Similarity = 0.28112528
# remiss		bargain		Cosine Similarity = 0.18323237
# nice		affable		Cosine Similarity = -0.038948134
# deal		affable		Cosine Similarity = -0.07305119
# benign		noble		Cosine Similarity = 0.23531143
# noble		aristocratic		Cosine Similarity = 0.14214388
# Word1 is not present in the model
# Word1 is not present in the model
# Word1 is not present in the model
# Word1 is not present in the model
# loyal		objection		Cosine Similarity = 0.09456172
# loyal		disapproval		Cosine Similarity = 0.0967596
# required		observe		Cosine Similarity = 0.24575338
# obvious		conspicuous		Cosine Similarity = 0.29732957
# watch		conspicuous		Cosine Similarity = -0.11826063
# irritate		offer		Cosine Similarity = 0.19192529
# irritate		bid		Cosine Similarity = -0.024354054
# proposal		omen		Cosine Similarity = 0.22228998
# proposal		premonition		Cosine Similarity = 0.20883064
# sign		omit		Cosine Similarity = 0.2118386
# remove		opportune		Cosine Similarity = 0.22529714
# remove		advantageous		Cosine Similarity = 0.21130224
# placate		pain		Cosine Similarity = -0.17071822
# placate		ache		Cosine Similarity = -0.08164575
# discomfort		paramount		Cosine Similarity = 0.19592606
# paramount		chief		Cosine Similarity = 0.26240364
# discomfort		chief		Cosine Similarity = 0.19680752
# dogmatic		inactive		Cosine Similarity = 0.17213023
# lethargic		pause		Cosine Similarity = 0.022498488
# lethargic		break		Cosine Similarity = 0.0043416508
# cease		diffuse		Cosine Similarity = 0.29998383
# disseminate		endure		Cosine Similarity = 0.27417386
# emanate		radical		Cosine Similarity = 0.042910915
# emanate		basic		Cosine Similarity = -0.0403357
# furor		rank		Cosine Similarity = 0.012861526
# rank		arrange		Cosine Similarity = 0.2913366
# furor		arrange		Cosine Similarity = -0.08442728
# fulfill		recalcitrant		Cosine Similarity = 0.2650922
# stubborn		receptacle		Cosine Similarity = 0.2367615
# stubborn		container		Cosine Similarity = 0.025072066
# Word1 is not present in the model
# Word1 is not present in the model
# Word1 is not present in the model
# Word1 is not present in the model
# slender		spontaneous		Cosine Similarity = 0.29780093
# slender		impromptu		Cosine Similarity = 0.19116259
# unplanned		spread		Cosine Similarity = 0.029203715
# unplanned		announce		Cosine Similarity = 0.10606081
# broadcast		stabilize		Cosine Similarity = 0.08177403
# stabilize		balance		Cosine Similarity = 0.21746513
# broadcast		balance		Cosine Similarity = 0.2924176
# duration		thrift		Cosine Similarity = -0.07241049
# thrift		conservation		Cosine Similarity = 0.10855056
# duration		conservation		Cosine Similarity = 0.09186341
# prudence		tough		Cosine Similarity = 0.15020898
# prudence		aggressive		Cosine Similarity = 0.21382353
# unyielding		transfer		Cosine Similarity = 0.08073719
# transfer		convey		Cosine Similarity = 0.021368764
# exchange		tumult		Cosine Similarity = 0.12235361
# exchange		agitation		Cosine Similarity = 0.23340946
# inflated		valid		Cosine Similarity = 0.22695522
# inflated		authorized		Cosine Similarity = 0.25759545
# restricted		nature		Euclidean Similarity = 0.44662692003577653
# restricted		aspect		Euclidean Similarity = 0.4921003323841671
# character		mandatory		Euclidean Similarity = 0.460377048256344
# requisite		contradict		Euclidean Similarity = 0.4415343607053216
# refute		negligent		Euclidean Similarity = 0.4686911786455013
# negligent		careless		Euclidean Similarity = 0.4809705313949279
# refute		careless		Euclidean Similarity = 0.45473936562710127
# negotiate		bargain		Euclidean Similarity = 0.498356842668896
# remiss		bargain		Euclidean Similarity = 0.43896261207570414
# nice		affable		Euclidean Similarity = 0.4095858004922681
# deal		affable		Euclidean Similarity = 0.40568639406723267
# benign		noble		Euclidean Similarity = 0.4470912421610807
# noble		aristocratic		Euclidean Similarity = 0.43292816953039315
# benign		aristocratic		Euclidean Similarity = 0.4767737691128348
# distinguished		beginner		Euclidean Similarity = 0.4925951659176099
# Word1 is not present in the model
# Word1 is not present in the model
# Word1 is not present in the model
# Word1 is not present in the model
# loyal		objection		Euclidean Similarity = 0.42631413700157816
# loyal		disapproval		Euclidean Similarity = 0.42661135699722363
# protest		obligatory		Euclidean Similarity = 0.4656747167003842
# obligatory		compulsory		Euclidean Similarity = 0.49000647336451747
# protest		compulsory		Euclidean Similarity = 0.4921326955940479
# required		observe		Euclidean Similarity = 0.44879129116959066
# observe		notice		Euclidean Similarity = 0.4919755097468662
# obvious		conspicuous		Euclidean Similarity = 0.45756733315125786
# watch		conspicuous		Euclidean Similarity = 0.4007212459635802
# definite		offend		Euclidean Similarity = 0.47774114298061304
# definite		anger		Euclidean Similarity = 0.4782736780337375
# irritate		offer		Euclidean Similarity = 0.4402806149856607
# irritate		bid		Euclidean Similarity = 0.41129736477912116
# proposal		omen		Euclidean Similarity = 0.4450051815368064
# proposal		premonition		Euclidean Similarity = 0.4428873528923865
# sign		omit		Euclidean Similarity = 0.4433573545344406
# sign		exclude		Euclidean Similarity = 0.475158833609262
# remove		opportune		Euclidean Similarity = 0.4454836657738167
# remove		advantageous		Euclidean Similarity = 0.44327341191689174
# placate		pain		Euclidean Similarity = 0.39522954632745855
# placate		ache		Euclidean Similarity = 0.40472505899762157
# discomfort		paramount		Euclidean Similarity = 0.4408922870150024
# paramount		chief		Euclidean Similarity = 0.451553899236279
# discomfort		chief		Euclidean Similarity = 0.4410274479731268
# leading		partisan		Euclidean Similarity = 0.4936400780798675
# partisan		biased		Euclidean Similarity = 0.49881382724929224
# leading		biased		Euclidean Similarity = 0.47794436374194427
# dogmatic		passive		Euclidean Similarity = 0.4933053704111974
# passive		inactive		Euclidean Similarity = 0.4674691417776059
# dogmatic		inactive		Euclidean Similarity = 0.4373008067948742
# lethargic		pause		Euclidean Similarity = 0.4169769286009584
# lethargic		break		Euclidean Similarity = 0.4147415395249012
# cease		permeate		Euclidean Similarity = 0.4835784889348221
# permeate		diffuse		Euclidean Similarity = 0.47397868753468203
# cease		diffuse		Euclidean Similarity = 0.45803701138206093
# disseminate		endure		Euclidean Similarity = 0.45354655757539514
# preserve		perplex		Euclidean Similarity = 0.4603612827782645
# perplex		astonish		Euclidean Similarity = 0.4992473445483648
# preserve		astonish		Euclidean Similarity = 0.4700717989915147
# baffle		persecute		Euclidean Similarity = 0.47353846803457506
# persecute		afflict		Euclidean Similarity = 0.48360087509964034
# baffle		afflict		Euclidean Similarity = 0.4892832112197084
# emanate		radical		Euclidean Similarity = 0.4195443482449833
# radical		basic		Euclidean Similarity = 0.47604597676101545
# emanate		basic		Euclidean Similarity = 0.4094244153008014
# fundamental		range		Euclidean Similarity = 0.46553152099235157
# range		anger		Euclidean Similarity = 0.4645098499904729
# fundamental		anger		Euclidean Similarity = 0.4616367899395568
# furor		rank		Euclidean Similarity = 0.4157849019261371
# rank		arrange		Euclidean Similarity = 0.45651356775031804
# furor		arrange		Euclidean Similarity = 0.40441571828942624
# classify		realize		Euclidean Similarity = 0.4701218002454454
# classify		accomplish		Euclidean Similarity = 0.47038301755526335
# fulfill		recalcitrant		Euclidean Similarity = 0.45200609506624334
# fulfill		obstinate		Euclidean Similarity = 0.49153018581107705
# stubborn		receptacle		Euclidean Similarity = 0.4473258645780175
# receptacle		container		Euclidean Similarity = 0.4674828968441786
# stubborn		container		Euclidean Similarity = 0.4172974051783014
# repository		reconcile		Euclidean Similarity = 0.46291018841253345
# repository		atone		Euclidean Similarity = 0.4892362414029728
# Word1 is not present in the model
# Word1 is not present in the model
# Word1 is not present in the model
# Word1 is not present in the model
# grieve		reliable		Euclidean Similarity = 0.4625196052084711
# grieve		dependable		Euclidean Similarity = 0.4810834305552664
# permit		scope		Euclidean Similarity = 0.4879623163104532
# extent		section		Euclidean Similarity = 0.4664486838820909
# extent		division		Euclidean Similarity = 0.478956585229965
# portion		settle		Euclidean Similarity = 0.48063160086450124
# portion		adjust		Euclidean Similarity = 0.48380478772844393
# compromise		shallow		Euclidean Similarity = 0.4812482541816312
# compromise		superficial		Euclidean Similarity = 0.4620519424852021
# trivial		shrewd		Euclidean Similarity = 0.4778676116685354
# shrewd		careful		Euclidean Similarity = 0.47236299580090274
# trivial		careful		Euclidean Similarity = 0.4766572226660334
# calculating		significant		Euclidean Similarity = 0.4924602335482476
# significant		distinctive		Euclidean Similarity = 0.480352663702607
# calculating		distinctive		Euclidean Similarity = 0.4665335129257067
# important		slight		Euclidean Similarity = 0.49829050274152775
# important		delicate		Euclidean Similarity = 0.4951277308036666
# slender		spontaneous		Euclidean Similarity = 0.4576506101756813
# slender		impromptu		Euclidean Similarity = 0.4401644105852813
# unplanned		spread		Euclidean Similarity = 0.4178138364852549
# spread		announce		Euclidean Similarity = 0.49406479071117143
# unplanned		announce		Euclidean Similarity = 0.42787784248697547
# broadcast		stabilize		Euclidean Similarity = 0.4246000327790953
# stabilize		balance		Euclidean Similarity = 0.44424158105918304
# broadcast		balance		Euclidean Similarity = 0.4567029558048874
# temper		mood		Euclidean Similarity = 0.49884924510217044
# twist		mood		Euclidean Similarity = 0.48718403355541734
# nature		inclination		Euclidean Similarity = 0.4714045685952111
# trend		cycle		Euclidean Similarity = 0.4818127989680718
# duration		thrift		Euclidean Similarity = 0.40575841091989523
# thrift		conservation		Euclidean Similarity = 0.4282192576886535
# duration		conservation		Euclidean Similarity = 0.4259502933553016
# prudence		tough		Euclidean Similarity = 0.4340880335860845
# prudence		aggressive		Euclidean Similarity = 0.4436685215511385
# unyielding		transfer		Euclidean Similarity = 0.42446220847345906
# transfer		convey		Euclidean Similarity = 0.41683653047995584
# unyielding		convey		Euclidean Similarity = 0.476125279528795
# exchange		tumult		Euclidean Similarity = 0.4301307188805188
# exchange		agitation		Euclidean Similarity = 0.4467842282324584
# commotion		turbulent		Euclidean Similarity = 0.47992087486186397
# turbulent		disordered		Euclidean Similarity = 0.49534385136415476
# commotion		disordered		Euclidean Similarity = 0.4783805403335156
# inflated		valid		Euclidean Similarity = 0.44574831668877
# valid		authorized		Euclidean Similarity = 0.4993716041263154
# inflated		authorized		Euclidean Similarity = 0.4507494402176165
# legitimate		variety		Euclidean Similarity = 0.4720787195550851
# variety		assortment		Euclidean Similarity = 0.48596416720103597
# legitimate		assortment		Euclidean Similarity = 0.4675322967107853
# diversify		verify		Euclidean Similarity = 0.48272320863139534
# verify		authenticate		Euclidean Similarity = 0.484164277476438

# %%
print(ed)
# Out:
# [['isolate', 'detach', 0.528712630784337], ['detach', 'quarantine', 0.5033920995611961], ['isolate', 'quarantine', 0.4680969671713597]]
