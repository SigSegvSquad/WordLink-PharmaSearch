# %% [markdown]
# # Cosine Similarity | Abstracts | Pretrained Model

# %% [markdown]
#  ⠀

# %% [markdown]
#  ⠀

# %% [markdown]
# # Loading Abstracts from File

# %% [markdown]
# ### Import Required Libraries

# %%
import glob
import os
import re

# %%
working_dir = "search_list/Abstracts/"

# %%
def filebrowser(curr_dir):
    "Returns files with an extension"
    return [f for f in glob.glob(curr_dir + "*.txt")]

# %%
file_list = filebrowser(working_dir)
print(file_list)
# Out:
# ['search_list/Abstracts/Anti-Toxoplasma gondii activity of 5-oxo-hexahydroquinoline derivatives.txt', 'search_list/Abstracts/pharmaceutical-care-in-a-patient-with-recurrent-infection-after-liver-transplant.txt', 'search_list/Abstracts/The effect of pramlintide, an antidiabetic amylin analogue on angiogenesis-related markers in vitro.txt', 'search_list/Abstracts/pharmacological-options-beyond-proton-pump-inhibitors-in-childrenwith-gastroesophageal-reflux-diseas.txt']

# %%
name_list = [i.replace(working_dir, '').replace('.txt', '') for i in file_list]
name_list
# Out:
# ['Anti-Toxoplasma gondii activity of 5-oxo-hexahydroquinoline derivatives',
#  'pharmaceutical-care-in-a-patient-with-recurrent-infection-after-liver-transplant',
#  'The effect of pramlintide, an antidiabetic amylin analogue on angiogenesis-related markers in vitro',
#  'pharmacological-options-beyond-proton-pump-inhibitors-in-childrenwith-gastroesophageal-reflux-diseas']

# %%
abstracts_list = []
contents = ''

for filepath in file_list:
    with open(filepath, 'r') as f:
        for line in f.readlines():
            line = line.replace('\n', ' ')
            contents += ''.join(e for e in line if (e.isalnum() or e==' '))
        abstracts_list.append(contents)
        f.close()

# %%
abstracts = dict()
for i in range(len(abstracts_list)):
    abstracts[name_list[i]] = abstracts_list[i]
    
abstracts
# Out:
# {'Anti-Toxoplasma gondii activity of 5-oxo-hexahydroquinoline derivatives': 'Abstract Background and purpose The aim of this study was to evaluate the in vitro and in vivo antiToxoplasma gondii T gondii effect of 5oxohexahydroquinoline compounds Moreover molecular docking study of the compounds into the active site of enoylacyl carrier protein reductase ENR as a necessary enzyme for the vitality of apicoplast was carried out Experimental approach A number of 5oxohexahydoquinoline derivatives Z1Z4 were synthesized The T gondii tachyzoites of RH strain were treated by different concentrations 164 μgmL of the compounds The viability of the encountered parasites with compounds was assessed using flow cytometry and propidium iodide PI staining Due to the high mortality effect of Z3 and Z4 in vitro their chemotherapy effect was assessed by inoculation of tachyzoites to four BALBc mice groups n  5 followed by the gavage of various concentrations of the compounds to the mice Molecular docking was done to study the binding affinity of the synthesized 5oxohexahydroquinolines into ENR enzyme active site byusing AutoDock Vina software Docking was performed by a Lamarckian Genetic Algorithm with 100 runs Findings  Results Flow cytometry assay results indicated compounds Z3 and Z4 had relevant mortality effect on parasite tachyzoites Besides in vivo experiments were also performed and a partial increase of mice longevity between control and experiment groups was recorded Molecular docking of Z3 and Z4 in the binding site of ENR enzyme indicated that the compounds were well accommodated within the binding site Therefore it could be suggested that these compounds may exert their antiT gondii activity through the inhibition of the ENR enzyme Conclusion and implications Compounds Z3 and Z4 are good leads in order to develop better antiT gondii agents as they demonstrated both in vitro and in vivo inhibitory effects on tachyzoites viability and infection Further studies on altering the route of administration along with additional pharmacokinetics evaluations are needed to improve the antiT gondii impacts of 5oxohexahydroquinoline compounds  Keywords Flow cytometry Molecular docking 5Oxohexahydroquinoline Propidium iodide Toxoplasma  ',
#  'pharmaceutical-care-in-a-patient-with-recurrent-infection-after-liver-transplant': 'Abstract Background and purpose The aim of this study was to evaluate the in vitro and in vivo antiToxoplasma gondii T gondii effect of 5oxohexahydroquinoline compounds Moreover molecular docking study of the compounds into the active site of enoylacyl carrier protein reductase ENR as a necessary enzyme for the vitality of apicoplast was carried out Experimental approach A number of 5oxohexahydoquinoline derivatives Z1Z4 were synthesized The T gondii tachyzoites of RH strain were treated by different concentrations 164 μgmL of the compounds The viability of the encountered parasites with compounds was assessed using flow cytometry and propidium iodide PI staining Due to the high mortality effect of Z3 and Z4 in vitro their chemotherapy effect was assessed by inoculation of tachyzoites to four BALBc mice groups n  5 followed by the gavage of various concentrations of the compounds to the mice Molecular docking was done to study the binding affinity of the synthesized 5oxohexahydroquinolines into ENR enzyme active site byusing AutoDock Vina software Docking was performed by a Lamarckian Genetic Algorithm with 100 runs Findings  Results Flow cytometry assay results indicated compounds Z3 and Z4 had relevant mortality effect on parasite tachyzoites Besides in vivo experiments were also performed and a partial increase of mice longevity between control and experiment groups was recorded Molecular docking of Z3 and Z4 in the binding site of ENR enzyme indicated that the compounds were well accommodated within the binding site Therefore it could be suggested that these compounds may exert their antiT gondii activity through the inhibition of the ENR enzyme Conclusion and implications Compounds Z3 and Z4 are good leads in order to develop better antiT gondii agents as they demonstrated both in vitro and in vivo inhibitory effects on tachyzoites viability and infection Further studies on altering the route of administration along with additional pharmacokinetics evaluations are needed to improve the antiT gondii impacts of 5oxohexahydroquinoline compounds  Keywords Flow cytometry Molecular docking 5Oxohexahydroquinoline Propidium iodide Toxoplasma  alCase description A case of a 57yearold liver transplant patient with biliary drainage catheter whose recurrent infection was managed by clinical pharmacists The suggestions about the choice of antibiotic regimen and the monitoring to other related infection factors such as biliary drainage catheter and concentration of tracrolimus were accepted and used to the patient The state of the infected patient was improved Conclusion The antibiotics distribution antibacterial effect and drug resistance could be taken into consideration for the patients with recurrent infection after liver transplant The resistance of antibiotics could be deferred by altering suitable antibiotics Close care to catheter and immunosuppressants could be necessary to prevent infection for the patients after transplant  Keywords Pharmaceutical care Recurrent infection Liver ',
#  'The effect of pramlintide, an antidiabetic amylin analogue on angiogenesis-related markers in vitro': 'Abstract Background and purpose The aim of this study was to evaluate the in vitro and in vivo antiToxoplasma gondii T gondii effect of 5oxohexahydroquinoline compounds Moreover molecular docking study of the compounds into the active site of enoylacyl carrier protein reductase ENR as a necessary enzyme for the vitality of apicoplast was carried out Experimental approach A number of 5oxohexahydoquinoline derivatives Z1Z4 were synthesized The T gondii tachyzoites of RH strain were treated by different concentrations 164 μgmL of the compounds The viability of the encountered parasites with compounds was assessed using flow cytometry and propidium iodide PI staining Due to the high mortality effect of Z3 and Z4 in vitro their chemotherapy effect was assessed by inoculation of tachyzoites to four BALBc mice groups n  5 followed by the gavage of various concentrations of the compounds to the mice Molecular docking was done to study the binding affinity of the synthesized 5oxohexahydroquinolines into ENR enzyme active site byusing AutoDock Vina software Docking was performed by a Lamarckian Genetic Algorithm with 100 runs Findings  Results Flow cytometry assay results indicated compounds Z3 and Z4 had relevant mortality effect on parasite tachyzoites Besides in vivo experiments were also performed and a partial increase of mice longevity between control and experiment groups was recorded Molecular docking of Z3 and Z4 in the binding site of ENR enzyme indicated that the compounds were well accommodated within the binding site Therefore it could be suggested that these compounds may exert their antiT gondii activity through the inhibition of the ENR enzyme Conclusion and implications Compounds Z3 and Z4 are good leads in order to develop better antiT gondii agents as they demonstrated both in vitro and in vivo inhibitory effects on tachyzoites viability and infection Further studies on altering the route of administration along with additional pharmacokinetics evaluations are needed to improve the antiT gondii impacts of 5oxohexahydroquinoline compounds  Keywords Flow cytometry Molecular docking 5Oxohexahydroquinoline Propidium iodide Toxoplasma  alCase description A case of a 57yearold liver transplant patient with biliary drainage catheter whose recurrent infection was managed by clinical pharmacists The suggestions about the choice of antibiotic regimen and the monitoring to other related infection factors such as biliary drainage catheter and concentration of tracrolimus were accepted and used to the patient The state of the infected patient was improved Conclusion The antibiotics distribution antibacterial effect and drug resistance could be taken into consideration for the patients with recurrent infection after liver transplant The resistance of antibiotics could be deferred by altering suitable antibiotics Close care to catheter and immunosuppressants could be necessary to prevent infection for the patients after transplant  Keywords Pharmaceutical care Recurrent infection Liver Abstract Background and purpose Irregularities of angiogenesis may participate in the pathogenesis of diabetes complications Pramlintide is an amylin analogue administered for the treatment of type 1 and type 2 diabetes The present investigation aimed at surveying the effect of pramlintide on angiogenesisrelated markers in human umbilical vein endothelial cells HUVECs Experimental approach The proliferation of cells was assessed using 345dimethylthiazol2yl25diphenyltetrazolium bromide MTT method The effect of pramlintide on migration was estimated by Transwell assay in vitro evaluation of angiogenesis was performed by tube formation assay The secretion of vascular endothelial growth factor VEGF to the supernatant of HUVECs was measured by an enzymelinked immunosorbent assay ELISA kit All experiments were performed in triplicate Findings  Results Pr ...
#  'pharmacological-options-beyond-proton-pump-inhibitors-in-childrenwith-gastroesophageal-reflux-diseas': 'Abstract Background and purpose The aim of this study was to evaluate the in vitro and in vivo antiToxoplasma gondii T gondii effect of 5oxohexahydroquinoline compounds Moreover molecular docking study of the compounds into the active site of enoylacyl carrier protein reductase ENR as a necessary enzyme for the vitality of apicoplast was carried out Experimental approach A number of 5oxohexahydoquinoline derivatives Z1Z4 were synthesized The T gondii tachyzoites of RH strain were treated by different concentrations 164 μgmL of the compounds The viability of the encountered parasites with compounds was assessed using flow cytometry and propidium iodide PI staining Due to the high mortality effect of Z3 and Z4 in vitro their chemotherapy effect was assessed by inoculation of tachyzoites to four BALBc mice groups n  5 followed by the gavage of various concentrations of the compounds to the mice Molecular docking was done to study the binding affinity of the synthesized 5oxohexahydroquinolines into ENR enzyme active site byusing AutoDock Vina software Docking was performed by a Lamarckian Genetic Algorithm with 100 runs Findings  Results Flow cytometry assay results indicated compounds Z3 and Z4 had relevant mortality effect on parasite tachyzoites Besides in vivo experiments were also performed and a partial increase of mice longevity between control and experiment groups was recorded Molecular docking of Z3 and Z4 in the binding site of ENR enzyme indicated that the compounds were well accommodated within the binding site Therefore it could be suggested that these compounds may exert their antiT gondii activity through the inhibition of the ENR enzyme Conclusion and implications Compounds Z3 and Z4 are good leads in order to develop better antiT gondii agents as they demonstrated both in vitro and in vivo inhibitory effects on tachyzoites viability and infection Further studies on altering the route of administration along with additional pharmacokinetics evaluations are needed to improve the antiT gondii impacts of 5oxohexahydroquinoline compounds  Keywords Flow cytometry Molecular docking 5Oxohexahydroquinoline Propidium iodide Toxoplasma  alCase description A case of a 57yearold liver transplant patient with biliary drainage catheter whose recurrent infection was managed by clinical pharmacists The suggestions about the choice of antibiotic regimen and the monitoring to other related infection factors such as biliary drainage catheter and concentration of tracrolimus were accepted and used to the patient The state of the infected patient was improved Conclusion The antibiotics distribution antibacterial effect and drug resistance could be taken into consideration for the patients with recurrent infection after liver transplant The resistance of antibiotics could be deferred by altering suitable antibiotics Close care to catheter and immunosuppressants could be necessary to prevent infection for the patients after transplant  Keywords Pharmaceutical care Recurrent infection Liver Abstract Background and purpose Irregularities of angiogenesis may participate in the pathogenesis of diabetes complications Pramlintide is an amylin analogue administered for the treatment of type 1 and type 2 diabetes The present investigation aimed at surveying the effect of pramlintide on angiogenesisrelated markers in human umbilical vein endothelial cells HUVECs Experimental approach The proliferation of cells was assessed using 345dimethylthiazol2yl25diphenyltetrazolium bromide MTT method The effect of pramlintide on migration was estimated by Transwell assay in vitro evaluation of angiogenesis was performed by tube formation assay The secretion of vascular endothelial growth factor VEGF to the supernatant of HUVECs was measured by an enzymelinked immunosorbent assay ELISA kit All experiments were performed in triplicate Findings  Results P ...

# %% [markdown]
#  ⠀

# %% [markdown]
# # Preprocess Abstracts

# %% [markdown]
# ### Import Required Libraries

# %%
# numpy imports
import numpy as np
from numpy import dot
from numpy.linalg import norm

# nltk imports
import nltk
from nltk import punkt
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize

# punctuation list
puncs="!#$%&'()*+,-./:;<=>?@[\]^_`{|}~"

# %% [markdown]
# ### Remove Punctuations and Stopwords from Abstracts

# %%
stop_words = set(stopwords.words('english'))

# %%
abstract_filtered = dict()

# %%
for key, abstract in abstracts.items():
  temp_list = []
  print(key,"\n")
  for word in word_tokenize(abstract):
    if word not in stop_words:
      if word not in puncs:
        temp_list.append(word)
  abstract_filtered[key] = temp_list
# Out:
# Anti-Toxoplasma gondii activity of 5-oxo-hexahydroquinoline derivatives
#
# pharmaceutical-care-in-a-patient-with-recurrent-infection-after-liver-transplant
#
# The effect of pramlintide, an antidiabetic amylin analogue on angiogenesis-related markers in vitro
#
# pharmacological-options-beyond-proton-pump-inhibitors-in-childrenwith-gastroesophageal-reflux-diseas

# %%
abstract_filtered
# Out:
# {'Anti-Toxoplasma gondii activity of 5-oxo-hexahydroquinoline derivatives': ['Abstract',
#   'Background',
#   'purpose',
#   'The',
#   'aim',
#   'study',
#   'evaluate',
#   'vitro',
#   'vivo',
#   'antiToxoplasma',
#   'gondii',
#   'T',
#   'gondii',
#   'effect',
#   '5oxohexahydroquinoline',
#   'compounds',
#   'Moreover',
#   'molecular',
#   'docking',
#   'study',
#   'compounds',
#   'active',
#   'site',
#   'enoylacyl',
#   'carrier',
#   'protein',
#   'reductase',
#   'ENR',
#   'necessary',
#   'enzyme',
#   'vitality',
#   'apicoplast',
#   'carried',
#   'Experimental',
#   'approach',
#   'A',
#   'number',
#   '5oxohexahydoquinoline',
#   'derivatives',
#   'Z1Z4',
#   'synthesized',
#   'The',
#   'T',
#   'gondii',
#   'tachyzoites',
#   'RH',
#   'strain',
#   'treated',
#   'different',
#   'concentrations',
#   '164',
#   'μgmL',
#   'compounds',
#   'The',
#   'viability',
#   'encountered',
#   'parasites',
#   'compounds',
#   'assessed',
#   'using',
#   'flow',
#   'cytometry',
#   'propidium',
#   'iodide',
#   'PI',
#   'staining',
#   'Due',
#   'high',
#   'mortality',
#   'effect',
#   'Z3',
#   'Z4',
#   'vitro',
#   'chemotherapy',
#   'effect',
#   'assessed',
#   'inoculation',
#   'tachyzoites',
#   'four',
#   'BALBc',
#   'mice',
#   'groups',
#   'n',
#   '5',
#   'followed',
#   'gavage',
#   'various',
#   'concentrations',
#   'compounds',
#   'mice',
#   'Molecular',
#   'docking',
#   'done',
#   'study',
#   'binding',
#   'affinity',
#   'synthesized',
#   '5oxohexahydroquinolines',
#   'ENR',
#   'enzyme',
#   'active',
#   'site',
#   'byusing',
#   'AutoDock',
#   'Vina',
#   'software',
#   'Docking',
#   'performed',
#   'Lamarckian',
#   'Genetic',
#   'Algorithm',
#   '100',
#   'runs',
#   'Findings',
#   'Results',
#   'Flow',
#   'cytometry',
#   'assay',
#   'results',
#   'indicated',
#   'compounds',
#   'Z3',
#   'Z4',
#   'relevant',
#   'mortality',
#   'effect',
#   'parasite',
#   'tachyzoites',
#   'Besides',
#   'vivo',
#   'experiments',
#   'also',
#   'performed',
#   'partial',
#   'increase',
#   'mice',
#   'longevity',
#   'control',
#   'experiment',
#   'groups',
#   'recorded',
#   'Molecular',
#   'docking',
#   'Z3',
#   'Z4',
#   'binding',
#   'site',
#   'ENR',
#   'enzyme',
#   'indicated',
#   'compounds',
#   'well',
#   'accommodated',
#   'within',
#   'binding',
#   'site',
#   'Therefore',
#   'could',
#   'suggested',
#   'compounds',
#   'may',
#   'exert',
#   'antiT',
#   'gondii',
#   'activity',
#   'inhibition',
#   'ENR',
#   'enzyme',
#   'Conclusion',
#   'implications',
#   'Compounds',
#   'Z3',
#   'Z4',
#   'good',
#   'leads',
#   'order',
#   'develop',
#   'better',
#   'antiT',
#   'gondii',
#   'agents',
#   'demonstrated',
#   'vitro',
#   'vivo',
#   'inhibitory',
#   'effects',
#   'tachyzoites',
#   'viability',
#   'infection',
#   'Further',
#   'studies',
#   'altering',
#   'route',
#   'administration',
#   'along',
#   'additional',
#   'pharmacokinetics',
#   'evaluations',
#   'needed',
#   'improve',
#   'antiT',
#   'gondii',
#   'impacts',
#   '5oxohexahydroquinoline',
#   'compounds',
#   'Keywords',
#   'Flow',
#   'cytometry',
#   'Molecular',
#   'docking',
#   '5Oxohexahydroquinoline',
#   'Propidium',
#   'iodide',
#   'Toxoplasma'],
#  'pharmaceutical-care-in-a-patient-with-recurrent-infection-after-liver-transplant': ['Abstract',
#   'Background',
#   'purpose',
#   'The',
#   'aim',
#   'study',
#   'evaluate',
#   'vitro',
#   'vivo',
#   'antiToxoplasma',
#   'gondii',
#   'T',
#   'gondii',
#   'effect',
#   '5oxohexahydroquinoline',
#   'compounds',
#   'Moreover',
#   'molecular',
#   'docking',
#   'study',
#   'compounds',
#   'active',
#   'site',
#   'enoylacyl',
#   'carrier',
#   'protein',
#   'reductase',
#   'ENR',
#   'necessary',
#   'enzyme',
#   'vitality',
#   'apicoplast',
#   'carried',
#   'Experimental',
#   'approach',
#   'A',
#   'number',
#   '5oxohexahydoquinoline',
#   'derivatives',
#   'Z1Z4',
#   'synthesized',
#   'The',
#   'T',
#   'gondii',
#   'tachyzoites',
#   'RH',
#   'strain',
#   'treated',
#   'different',
#   'concentrations',
#   '164',
#   'μgmL',
#   'compounds',
#   'The',
#   'viability',
#   'encountered',
#   'parasites',
#   'compounds',
#   'assessed',
#   'using',
#   'flow',
#   'cytometry',
#   'propidium',
#   'iodide',
#   'PI',
#   'staining',
#   'Due',
#   'high',
#   'mortality',
#   'effect',
#   'Z3',
#   'Z4',
#   'vitro',
#   'chemotherapy',
#   'effect',
#   'assessed',
#   'inoculation',
#   'tachyzoites',
#   'four',
#   'BALBc',
#   'mice',
#   'groups',
#   'n',
#   '5',
#   'followed',
#   'gavage',
#   'various',
#   'concentrations',
#   'compounds',
#   'mice',
#   'Molecular',
#   'docking',
#   'done',
#   'study',
#   'binding',
#   'affinity',
#   'synthesized',
#   '5oxohexahydroquinolines',
#   'ENR',
#   'enzyme',
#   'active',
#   'site',
#   'byusing',
#   'AutoDock',
#   'Vina',
#   'software',
#   'Docking',
#   'performed',
#   'Lamarckian',
#   'Genetic',
#   'Algorithm',
#   '100',
#   'runs',
#   'Findings',
#   'Results',
#   'Flow',
#   'cytometry',
#   'assay',
#   'results',
#   'indicated',
#   'compounds',
#   'Z3',
#   'Z4',
#   'relevant',
#   'mortality',
#   'effect',
#   'parasite',
#   'tachyzoites',
#   'Besides',
#   'vivo',
#   'experiments',
#   'also',
#   'performed',
#   'partial',
#   'increase',
#   'mice',
#   'longevity',
#   'control',
#   'experiment',
#   'groups',
#   'recorded',
#   'Molecular',
#   'docking',
#   'Z3',
#   'Z4',
#   'binding',
#   'site',
#   'ENR',
#   'enzyme',
#   'indicated',
#   'compounds',
#   'well',
#   'accommodated',
#   'within',
#   'binding',
#   'site',
#   'Therefore',
#   'could',
#   'suggested',
#   'compounds',
#   'may',
#   'exert',
#   'antiT',
#   'gondii',
#   'activity',
#   'inhibition',
#   'ENR',
#   'enzyme',
#   'Conclusion',
#   'implications',
#   'Compounds',
#   'Z3',
#   'Z4',
#   'good',
#   'leads',
#   'order',
#   'develop',
#   'better',
#   'antiT',
#   'gondii',
#   'agents',
#   'demonstrated',
#   'vitro',
#   'vivo',
#   'inhibitory',
#   'effects',
#   'tachyzoites',
#   'viability',
#   'infection',
#   'Further',
#   'studies',
#   'altering',
#   'route',
#   'administration',
#   'along',
#   'additional',
#   'pharmacokinetics',
#   'evaluations',
#   'needed',
#   'improve',
#   'antiT',
#   'gondii',
#   'impacts',
#   '5oxohexahydroquinoline',
#   'compounds',
#   'Keywords',
#   'Flow',
#   'cytometry',
#   'Molecular',
#   'docking',
#   '5Oxohexahydroquinoline',
#   'Propidium',
#   'iodide',
#   'Toxoplasma',
#   'alCase',
#   'description',
#   'A',
#   'case',
#   '57yearold',
#   'liver',
#   'transplant',
#   'patient',
#   'biliary',
#   'drainage',
#   'catheter',
#   'whose',
#   'recurrent',
#   'infection',
#   'managed',
#   'clinical',
#   'pharmacists',
#   'The',
#   'suggestions',
#   'choice',
#   'antibiotic',
#   'regimen',
#   'monitoring',
#   'related',
#   'infection',
#   'factors',
#   'biliary',
#   'drainage',
#   'catheter',
#   'concentration',
#   'tracrolimus',
#   'accepted',
#   'used',
#   'patient',
#   'The',
#   'state',
#   'infected',
#   'patient',
#   'improved',
#   'Conclusion',
#   'The',
#   'antibiotics',
#   'distribution',
#   'antibacterial',
#   'effect',
#   'drug',
#   'resistance',
#   'could',
#   'taken',
#   'consideration',
#   'patients',
#   'recurrent',
#   'infection',
#   'liver',
#   'transplant',
#   'The',
#   'resistance',
#   'antibiotics',
#   'could',
#   'deferred',
#   'altering',
#   'suitable',
#   'antibiotics',
#   'Close',
#   'care',
#   'catheter',
#   'immunosuppressants',
#   'could',
#   'necessary',
#   'prevent',
#   'infection',
#   'patients',
#   'transplant',
#   'Keywords',
#   'Pharmaceutical',
#   'care',
#   'Recurrent',
#   'infection',
#   'Liver'],
#  'The effect of pramlintide, an antidiabetic amylin analogue on angiogenesis-related markers in vitro': ['Abstract',
#   'Background',
#   'purpose',
#   'The',
#   'aim',
#   'study',
#   'evaluate',
#   'vitro',
#   'vivo',
#   'antiToxoplasma',
#   'gondii',
#   'T',
#   'gondii',
#   'effect',
#   '5oxohexahydroquinoline',
#   'compounds',
#   'Moreover',
#   'molecular',
#   'docking',
#   'study',
#   'compounds',
#   'active',
#   'site',
#   'enoylacyl',
#   'carrier',
#   'protein',
#   'reductase',
#   'ENR',
#   'necessary',
#   'enzyme',
#   'vitality',
#   'apicoplast',
#   'carried',
#   'Experimental',
#   'approach',
#   'A',
#   'number',
#   '5oxohexahydoquinoline',
#   'derivatives',
#   'Z1Z4',
#   'synthesized',
#   'The',
#   'T',
#   'gondii',
#   'tachyzoites',
#   'RH',
#   'strain',
#   'treated',
#   'different',
#   'concentrations',
#   '164',
#   'μgmL',
#   'compounds',
#   'The',
#   'viability',
#   'encountered',
#   'parasites',
#   'compounds',
#   'assessed',
#   'using',
#   'flow',
#   'cytometry',
#   'propidium',
#   'iodide',
#   'PI',
#   'staining',
#   'Due',
#   'high',
#   'mortality',
#   'effect',
#   'Z3',
#   'Z4',
#   'vitro',
#   'chemotherapy',
#   'effect',
#   'assessed',
#   'inoculation',
#   'tachyzoites',
#   'four',
#   'BALBc',
#   'mice',
#   'groups',
#   'n',
#   '5',
#   'followed',
#   'gavage',
#   'various',
#   'concentrations',
#   'compounds',
#   'mice',
#   'Molecular',
#   'docking',
#   'done',
#   'study',
#   'binding',
#   'affinity',
#   'synthesized',
#   '5oxohexahydroquinolines',
#   'ENR',
#   'enzyme',
#   'active',
#   'site',
#   'byusing',
#   'AutoDock',
#   'Vina',
#   'software',
#   'Docking',
#   'performed',
#   'Lamarckian',
#   'Genetic',
#   'Algorithm',
#   '100',
#   'runs',
#   'Findings',
#   'Results',
#   'Flow',
#   'cytometry',
#   'assay',
#   'results',
#   'indicated',
#   'compounds',
#   'Z3',
#   'Z4',
#   'relevant',
#   'mortality',
#   'effect',
#   'parasite',
#   'tachyzoites',
#   'Besides',
#   'vivo',
#   'experiments',
#   'also',
#   'performed',
#   'partial',
#   'increase',
#   'mice',
#   'longevity',
#   'control',
#   'experiment',
#   'groups',
#   'recorded',
#   'Molecular',
#   'docking',
#   'Z3',
#   'Z4',
#   'binding',
#   'site',
#   'ENR',
#   'enzyme',
#   'indicated',
#   'compounds',
#   'well',
#   'accommodated',
#   'within',
#   'binding',
#   'site',
#   'Therefore',
#   'could',
#   'suggested',
#   'compounds',
#   'may',
#   'exert',
#   'antiT',
#   'gondii',
#   'activity',
#   'inhibition',
#   'ENR',
#   'enzyme',
#   'Conclusion',
#   'implications',
#   'Compounds',
#   'Z3',
#   'Z4',
#   'good',
#   'leads',
#   'order',
#   'develop',
#   'better',
#   'antiT',
#   'gondii',
#   'agents',
#   'demonstrated',
#   'vitro',
#   'vivo',
#   'inhibitory',
#   'effects',
#   'tachyzoites',
#   'viability',
#   'infection',
#   'Further',
#   'studies',
#   'altering',
#   'route',
#   'administration',
#   'along',
#   'additional',
#   'pharmacokinetics',
#   'evaluations',
#   'needed',
#   'improve',
#   'antiT',
#   'gondii',
#   'impacts',
#   '5oxohexahydroquinoline',
#   'compounds',
#   'Keywords',
#   'Flow',
#   'cytometry',
#   'Molecular',
#   'docking',
#   '5Oxohexahydroquinoline',
#   'Propidium',
#   'iodide',
#   'Toxoplasma',
#   'alCase',
#   'description',
#   'A',
#   'case',
#   '57yearold',
#   'liver',
#   'transplant',
#   'patient',
#   'biliary',
#   'drainage',
#   'catheter',
#   'whose',
#   'recurrent',
#   'infection',
#   'managed',
#   'clinical',
#   'pharmacists',
#   'The',
#   'suggestions',
#   'choice',
#   'antibiotic',
#   'regimen',
#   'monitoring',
#   'related',
#   'infection',
#   'factors',
#   'biliary',
#   'drainage',
#   'catheter',
#   'concentration',
#   'tracrolimus',
#   'accepted',
#   'used',
#   'patient',
#   'The',
#   'state',
#   'infected',
#   'patient',
#   'improved',
#   'Conclusion',
#   'The',
#   'antibiotics',
#   'distribution',
#   'antibacterial',
#   'effect',
#   'drug',
#   'resistance',
#   'could',
#   'taken',
#   'consideration',
#   'patients',
#   'recurrent',
#   'infection',
#   'liver',
#   'transplant',
#   'The',
#   'resistance',
#   'antibiotics',
#   'could',
#   'deferred',
#   'altering',
#   'suitable',
#   'antibiotics',
#   'Close',
#   'care',
#   'catheter',
#   'immunosuppressants',
#   'could',
#   'necessary',
#   'prevent',
#   'infection',
#   'patients',
#   'transplant',
#   'Keywords',
#   'Pharmaceutical',
#   'care',
#   'Recurrent',
#   'infection',
#   'Liver',
#   'Abstract',
#   'Background',
#   'purpose',
#   'Irregularities',
#   'angiogenesis',
#   'may',
#   'participate',
#   'pathogenesis',
#   'diabetes',
#   'complications',
#   'Pramlintide',
#   'amylin',
#   'analogue',
#   'administered',
#   'treatment',
#   'type',
#   '1',
#   'type',
#   '2',
#   'diabetes',
#   'The',
#   'present',
#   'investigation',
#   'aimed',
#   'surveying',
#   'effect',
#   'pramlintide',
#   'angiogenesisrelated',
#   'markers',
#   'human',
#   'umbilical',
#   'vein',
#   'endothelial',
#   'cells',
#   'HUVECs',
#   'Experimental',
#   'approach',
#   'The',
#   'proliferation',
#   'cells',
#   'assessed',
#   'using',
#   '345dimethylthiazol2yl25diphenyltetrazolium',
#   'bromide',
#   'MTT',
#   'method',
#   'The',
#   'effect',
#   'pramlintide',
#   'migration',
#   'estimated',
#   'Transwell',
#   'assay',
#   'vitro',
#   'evaluation',
#   'angiogenesis',
#   'performed',
#   'tube',
#   'formation',
#   'assay',
#   'The',
#   'secretion',
#   'vascular',
#   'endothelial',
#   'growth',
#   'factor',
#   'VEGF',
#   'supernatant',
#   'HUVECs',
#   'measured',
#   'enzymelinked',
#   'immunosorbent',
#   'assay',
#   'ELISA',
#   'kit',
#   'All',
#   'experiments',
#   'performed',
#   'triplicate',
#   'Findings',
#   'Results',
#   'Pramlintide',
#   'exhibited',
#   'inhibitory',
#   'effect',
#   'HUVECs',
#   'proliferation',
#   'It',
#   'significantly',
#   'increased',
#   'cell',
#   'migration',
#   'concentration',
#   '1',
#   'µgmL',
#   'Pramlintide',
#   '1',
#   'µgmL',
#   'also',
#   'enhanced',
#   'average',
#   'tubules',
#   'length',
#   'size',
#   'mean',
#   'number',
#   'junctions',
#   'However',
#   'significant',
#   'change',
#   'VEGF',
#   'release',
#   'HUVECs',
#   'Conclusion',
#   'implications',
#   'Findings',
#   'research',
#   'revealed',
#   'effect',
#   'pramlintide',
#   'angiogenesisrelated',
#   'markers',
#   'via',
#   'enhancing',
#   'migration',
#   'tubulogenesis',
#   'vitro',
#   'suggesting',
#   'worthwhile',
#   'proposition',
#   'clinical',
#   'researches',
#   'improving',
#   'vascular',
#   'complications',
#   'healing',
#   'diabetic',
#   'wounds',
#   'Keywords',
#   'Angiogenesis',
#   'Cell',
#   'migration',
#   'Diabetes',
#   'mellitus',
#   'HUVEC',
#   'Pramlintide',
#   'VEGF'],
#  'pharmacological-options-beyond-proton-pump-inhibitors-in-childrenwith-gastroesophageal-reflux-diseas': ['Abstract',
#   'Background',
#   'purpose',
#   'The',
#   'aim',
#   'study',
#   'evaluate',
#   'vitro',
#   'vivo',
#   'antiToxoplasma',
#   'gondii',
#   'T',
#   'gondii',
#   'effect',
#   '5oxohexahydroquinoline',
#   'compounds',
#   'Moreover',
#   'molecular',
#   'docking',
#   'study',
#   'compounds',
#   'active',
#   'site',
#   'enoylacyl',
#   'carrier',
#   'protein',
#   'reductase',
#   'ENR',
#   'necessary',
#   'enzyme',
#   'vitality',
#   'apicoplast',
#   'carried',
#   'Experimental',
#   'approach',
#   'A',
#   'number',
#   '5oxohexahydoquinoline',
#   'derivatives',
#   'Z1Z4',
#   'synthesized',
#   'The',
#   'T',
#   'gondii',
#   'tachyzoites',
#   'RH',
#   'strain',
#   'treated',
#   'different',
#   'concentrations',
#   '164',
#   'μgmL',
#   'compounds',
#   'The',
#   'viability',
#   'encountered',
#   'parasites',
#   'compounds',
#   'assessed',
#   'using',
#   'flow',
#   'cytometry',
#   'propidium',
#   'iodide',
#   'PI',
#   'staining',
#   'Due',
#   'high',
#   'mortality',
#   'effect',
#   'Z3',
#   'Z4',
#   'vitro',
#   'chemotherapy',
#   'effect',
#   'assessed',
#   'inoculation',
#   'tachyzoites',
#   'four',
#   'BALBc',
#   'mice',
#   'groups',
#   'n',
#   '5',
#   'followed',
#   'gavage',
#   'various',
#   'concentrations',
#   'compounds',
#   'mice',
#   'Molecular',
#   'docking',
#   'done',
#   'study',
#   'binding',
#   'affinity',
#   'synthesized',
#   '5oxohexahydroquinolines',
#   'ENR',
#   'enzyme',
#   'active',
#   'site',
#   'byusing',
#   'AutoDock',
#   'Vina',
#   'software',
#   'Docking',
#   'performed',
#   'Lamarckian',
#   'Genetic',
#   'Algorithm',
#   '100',
#   'runs',
#   'Findings',
#   'Results',
#   'Flow',
#   'cytometry',
#   'assay',
#   'results',
#   'indicated',
#   'compounds',
#   'Z3',
#   'Z4',
#   'relevant',
#   'mortality',
#   'effect',
#   'parasite',
#   'tachyzoites',
#   'Besides',
#   'vivo',
#   'experiments',
#   'also',
#   'performed',
#   'partial',
#   'increase',
#   'mice',
#   'longevity',
#   'control',
#   'experiment',
#   'groups',
#   'recorded',
#   'Molecular',
#   'docking',
#   'Z3',
#   'Z4',
#   'binding',
#   'site',
#   'ENR',
#   'enzyme',
#   'indicated',
#   'compounds',
#   'well',
#   'accommodated',
#   'within',
#   'binding',
#   'site',
#   'Therefore',
#   'could',
#   'suggested',
#   'compounds',
#   'may',
#   'exert',
#   'antiT',
#   'gondii',
#   'activity',
#   'inhibition',
#   'ENR',
#   'enzyme',
#   'Conclusion',
#   'implications',
#   'Compounds',
#   'Z3',
#   'Z4',
#   'good',
#   'leads',
#   'order',
#   'develop',
#   'better',
#   'antiT',
#   'gondii',
#   'agents',
#   'demonstrated',
#   'vitro',
#   'vivo',
#   'inhibitory',
#   'effects',
#   'tachyzoites',
#   'viability',
#   'infection',
#   'Further',
#   'studies',
#   'altering',
#   'route',
#   'administration',
#   'along',
#   'additional',
#   'pharmacokinetics',
#   'evaluations',
#   'needed',
#   'improve',
#   'antiT',
#   'gondii',
#   'impacts',
#   '5oxohexahydroquinoline',
#   'compounds',
#   'Keywords',
#   'Flow',
#   'cytometry',
#   'Molecular',
#   'docking',
#   '5Oxohexahydroquinoline',
#   'Propidium',
#   'iodide',
#   'Toxoplasma',
#   'alCase',
#   'description',
#   'A',
#   'case',
#   '57yearold',
#   'liver',
#   'transplant',
#   'patient',
#   'biliary',
#   'drainage',
#   'catheter',
#   'whose',
#   'recurrent',
#   'infection',
#   'managed',
#   'clinical',
#   'pharmacists',
#   'The',
#   'suggestions',
#   'choice',
#   'antibiotic',
#   'regimen',
#   'monitoring',
#   'related',
#   'infection',
#   'factors',
#   'biliary',
#   'drainage',
#   'catheter',
#   'concentration',
#   'tracrolimus',
#   'accepted',
#   'used',
#   'patient',
#   'The',
#   'state',
#   'infected',
#   'patient',
#   'improved',
#   'Conclusion',
#   'The',
#   'antibiotics',
#   'distribution',
#   'antibacterial',
#   'effect',
#   'drug',
#   'resistance',
#   'could',
#   'taken',
#   'consideration',
#   'patients',
#   'recurrent',
#   'infection',
#   'liver',
#   'transplant',
#   'The',
#   'resistance',
#   'antibiotics',
#   'could',
#   'deferred',
#   'altering',
#   'suitable',
#   'antibiotics',
#   'Close',
#   'care',
#   'catheter',
#   'immunosuppressants',
#   'could',
#   'necessary',
#   'prevent',
#   'infection',
#   'patients',
#   'transplant',
#   'Keywords',
#   'Pharmaceutical',
#   'care',
#   'Recurrent',
#   'infection',
#   'Liver',
#   'Abstract',
#   'Background',
#   'purpose',
#   'Irregularities',
#   'angiogenesis',
#   'may',
#   'participate',
#   'pathogenesis',
#   'diabetes',
#   'complications',
#   'Pramlintide',
#   'amylin',
#   'analogue',
#   'administered',
#   'treatment',
#   'type',
#   '1',
#   'type',
#   '2',
#   'diabetes',
#   'The',
#   'present',
#   'investigation',
#   'aimed',
#   'surveying',
#   'effect',
#   'pramlintide',
#   'angiogenesisrelated',
#   'markers',
#   'human',
#   'umbilical',
#   'vein',
#   'endothelial',
#   'cells',
#   'HUVECs',
#   'Experimental',
#   'approach',
#   'The',
#   'proliferation',
#   'cells',
#   'assessed',
#   'using',
#   '345dimethylthiazol2yl25diphenyltetrazolium',
#   'bromide',
#   'MTT',
#   'method',
#   'The',
#   'effect',
#   'pramlintide',
#   'migration',
#   'estimated',
#   'Transwell',
#   'assay',
#   'vitro',
#   'evaluation',
#   'angiogenesis',
#   'performed',
#   'tube',
#   'formation',
#   'assay',
#   'The',
#   'secretion',
#   'vascular',
#   'endothelial',
#   'growth',
#   'factor',
#   'VEGF',
#   'supernatant',
#   'HUVECs',
#   'measured',
#   'enzymelinked',
#   'immunosorbent',
#   'assay',
#   'ELISA',
#   'kit',
#   'All',
#   'experiments',
#   'performed',
#   'triplicate',
#   'Findings',
#   'Results',
#   'Pramlintide',
#   'exhibited',
#   'inhibitory',
#   'effect',
#   'HUVECs',
#   'proliferation',
#   'It',
#   'significantly',
#   'increased',
#   'cell',
#   'migration',
#   'concentration',
#   '1',
#   'µgmL',
#   'Pramlintide',
#   '1',
#   'µgmL',
#   'also',
#   'enhanced',
#   'average',
#   'tubules',
#   'length',
#   'size',
#   'mean',
#   'number',
#   'junctions',
#   'However',
#   'significant',
#   'change',
#   'VEGF',
#   'release',
#   'HUVECs',
#   'Conclusion',
#   'implications',
#   'Findings',
#   'research',
#   'revealed',
#   'effect',
#   'pramlintide',
#   'angiogenesisrelated',
#   'markers',
#   'via',
#   'enhancing',
#   'migration',
#   'tubulogenesis',
#   'vitro',
#   'suggesting',
#   'worthwhile',
#   'proposition',
#   'clinical',
#   'researches',
#   'improving',
#   'vascular',
#   'complications',
#   'healing',
#   'diabetic',
#   'wounds',
#   'Keywords',
#   'Angiogenesis',
#   'Cell',
#   'migration',
#   'Diabetes',
#   'mellitus',
#   'HUVEC',
#   'Pramlintide',
#   'VEGF',
#   'Pharmacological',
#   'treatment',
#   'gastroesophageal',
#   'reflux',
#   'GER',
#   'disease',
#   'mostly',
#   'based',
#   'acid',
#   'control',
#   'However',
#   'different',
#   'molecules',
#   'proposed',
#   'patients',
#   'persisting',
#   'symptoms',
#   'limit',
#   'adverse',
#   'effects',
#   'proton',
#   'pump',
#   'inhibitors',
#   'PPI',
#   'This',
#   'paper',
#   'focuses',
#   'acid',
#   'inhibitors',
#   'alginate',
#   'prokinetics',
#   'drug',
#   'acting',
#   'lower',
#   'esophageal',
#   'sphincter',
#   'esophageal',
#   'hypersensitivity',
#   'Mechanism',
#   'action',
#   'indications',
#   'efficacy',
#   'limits',
#   'recent',
#   'advances',
#   'reported',
#   'Pediatric',
#   'data',
#   'possible',
#   'adverse',
#   'effects',
#   'also',
#   'considered',
#   'Keywords',
#   'Reflux',
#   'Ranitidine',
#   'Alginate',
#   'Prokinetics',
#   'Baclofen']}

# %% [markdown]
#  ⠀

# %% [markdown]
# # Word2Vec Search

# %% [markdown]
# ### Import Required Libraries

# %%
from gensim.models import Word2Vec
from gensim.test.utils import common_texts, get_tmpfile
import gensim.downloader as api
from pprint import pprint

# %% [markdown]
# ### Load Model from Memory

# %%
model = api.load("glove-twitter-50")

# %% [markdown]
# ### Convert Abstracts to Vectors

# %%
#Abstract to vector
abstract2vec=dict()
for key, abstract in abstract_filtered.items():
  centroid = np.zeros((50,))
  for word in abstract:
    try:
      centroid += model[word.lower()]
    except:
      pass
  centroid /= len(abstract)
  abstract2vec[key] = centroid

abstract2vec
# Out:
# {'Anti-Toxoplasma gondii activity of 5-oxo-hexahydroquinoline derivatives': array([-0.07997122,  0.1322542 , -0.28960934,  0.10028079,  0.22969557,
#          0.16735991,  0.09946941, -0.48924301, -0.03658194, -0.3161375 ,
#         -0.00695457, -0.19977862, -1.64909231,  0.23055069,  0.21412665,
#         -0.08681255,  0.32984696, -0.01174029,  0.21621427, -0.12933005,
#         -0.0781037 ,  0.15181748,  0.0524821 , -0.12120208, -0.32243147,
#          0.48045451, -0.00462152,  0.24578823,  0.00185973,  0.32224417,
#          0.29715275, -0.11596642,  0.13682656, -0.21628157,  0.09412573,
#         -0.25494326, -0.06640304,  0.20673274,  0.0900704 , -0.10836769,
#          0.28670992, -0.06118384,  0.05629857, -0.19056601,  0.03675359,
#         -0.18041929, -0.12160913,  0.17665429, -0.09784039, -0.04430752]),
#  'pharmaceutical-care-in-a-patient-with-recurrent-infection-after-liver-transplant': array([-0.11085061,  0.1674317 , -0.38085551,  0.08403651,  0.19086554,
#          0.12107865,  0.13377114, -0.49691224, -0.02608446, -0.33377833,
#          0.00850345, -0.27566284, -1.84859128,  0.23436853,  0.28516143,
#         -0.02106336,  0.3229586 , -0.03928715,  0.21670241, -0.17553052,
#         -0.13481011,  0.21635653,  0.05438992, -0.07833132, -0.26281422,
#          0.58492633,  0.00916923,  0.26218167, -0.01490328,  0.38027941,
#          0.25620314, -0.15260359,  0.10774412, -0.22003243,  0.11267623,
#         -0.22029204, -0.1063396 ,  0.2413668 ,  0.03910745, -0.09553322,
#          0.27006285, -0.06731473,  0.07941256, -0.15756699,  0.10358682,
#         -0.20600194, -0.07846174,  0.22097142, -0.09103836, -0.03591302]),
#  'The effect of pramlintide, an antidiabetic amylin analogue on angiogenesis-related markers in vitro': array([-0.13485804,  0.14482816, -0.31274043,  0.07477028,  0.21762387,
#          0.11712804,  0.15040278, -0.45902654, -0.03851435, -0.32714541,
#          0.02054714, -0.25875599, -1.78687838,  0.23681584,  0.25003942,
#          0.00806139,  0.30878336, -0.00301503,  0.21880043, -0.16889317,
#         -0.17614501,  0.18678438,  0.06782161, -0.06982455, -0.25271692,
#          0.56541032,  0.00212276,  0.26127005, -0.02558966,  0.36789624,
#          0.25969064, -0.17120658,  0.11383964, -0.26704788,  0.1494814 ,
#         -0.2129525 , -0.12343697,  0.24782439,  0.06174285, -0.14432996,
#          0.24503295, -0.06937967,  0.08635741, -0.11796317,  0.0743489 ,
#         -0.20030045, -0.08789667,  0.20916517, -0.11271665, -0.02856824]),
#  'pharmacological-options-beyond-proton-pump-inhibitors-in-childrenwith-gastroesophageal-reflux-diseas': array([-0.13883161,  0.15967356, -0.32627957,  0.07715938,  0.21763763,
#          0.12507596,  0.15809036, -0.46773837, -0.03752382, -0.32355827,
#          0.01937394, -0.26789626, -1.79313955,  0.241625  ,  0.25869321,
#          0.00382517,  0.31821374, -0.01343474,  0.23636438, -0.17935226,
#         -0.1827802 ,  0.19134357,  0.07004399, -0.06431568, -0.24733132,
#          0.58743112,  0.00392096,  0.28364169, -0.05763861,  0.37228901,
#          0.24988841, -0.17734394,  0.11013002, -0.2673619 ,  0.14672187,
#         -0.21297246, -0.14592391,  0.25852928,  0.06254647, -0.1485504 ,
#          0.23636162, -0.07249843,  0.08873981, -0.11032188,  0.07440596,
#         -0.21630671, -0.09689009,  0.21116581, -0.11371739, -0.01419555])}

# %% [markdown]
# ### Search for a Query

# %%
def search(query):
    results = dict()
    query = query.lower()
    #Abstract to vector
    query2vec=np.zeros((50,))
    query_tokenized=word_tokenize(query)
    for word in query_tokenized:
      if word not in stop_words:
        if word not in puncs:
          try:
            query2vec+=model[word]
          except:
            pass
    query2vec/=len(query_tokenized)
    return results, query2vec

# %%
query = 'the structures phospholipids'

results, query2vec = search(query)

# %%
for key, abstract_vec in abstract2vec.items():
  #round to 4th decimal
  cos_sim = round(dot(abstract_vec, query2vec)/(norm(abstract_vec)*norm(query2vec)), 6)*100
  results[key]=cos_sim
    
pprint(results)
# Out:
# {'Anti-Toxoplasma gondii activity of 5-oxo-hexahydroquinoline derivatives': 65.2364,
#  'The effect of pramlintide, an antidiabetic amylin analogue on angiogenesis-related markers in vitro': 62.3069,
#  'pharmaceutical-care-in-a-patient-with-recurrent-infection-after-liver-transplant': 61.968999999999994,
#  'pharmacological-options-beyond-proton-pump-inhibitors-in-childrenwith-gastroesophageal-reflux-diseas': 62.164500000000004}
